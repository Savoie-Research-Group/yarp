# %% [markdown]
# # YARP Tutorial 2: Product Enumeration and The Reaction Class

# %% [markdown]
# ## Section A: Product Enumeration
#
# Here we will cover the two modes of enumeration: concerted and sequential.
#
# We will also cover the post-enumeration filtering options:
# - Lewis score
# - Formal charge
# - Strained rings
#
# For this tutorial, we will be using the `enumerate_products()` function, which conveniently wraps all underlying enumeration codes.
# This function returns a list of `yarpecule` objects generated by enumeration.
#
# Enumerated products are then processed through a separate filtering function `filter_enum_products()`, where various "sanity checks" are applied to remove unphysical or unstable products.

# %%
import yarp as yp
from yarp.reaction.enum import enumerate_products
from yarp.reaction.filters import filter_enum_products

# %% [markdown]
# ### Concerted vs. Sequential Enumeration
#
# Concerted enumeration
# - Bonds are defined by bond order
# - Bond breaking and forming happen in one-shot
# - Bond formation is restricted to atoms involved in bond breakage
# - More rigorous "reasonability" checks are baked into the product enumeration routine (i.e. no dangling bonds, no zwitterions)
#
# Sequential enumeration
# - Bonds are defined by connectivity
# - Bond breaking and forming happen in two distinct steps
# - Bond formation can occur between any atoms in the molecule/system
# - Valence and pi bond electrons are allowed to move freely to fill in the final structure
# - "Reasonability" checks are performed after product enumeration routine to **allow for more comprehensive enumeration**
#
# In short, sequential *should* find all of the same structures as concerted enumeration, plus some additional structures - which may be unphysical!

# %%
haa = yp.yarpecule('CC=O')
haa.draw_bmats(show_inline=True)

# %% [markdown]
# For concerted enumeration, only 3 possible structures can be formed (excluding the reforming of the original reactant via H exchange).
#
# Notice also that the application of "reasonability filters" after enumeration does not eliminate any products.

# %%
haa_conc_b2f2 = enumerate_products(haa, n_break=2, n_form=2, mode='concerted', verbose=True)
haa_conc_b2f2 = filter_enum_products(haa_conc_b2f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False, verbose=True)
for _ in haa_conc_b2f2:
    _.draw_bmats(show_inline=True)
# Out:
#   * Product enumeration with break 2, form 2 will be performed in concerted mode.
# Enumerating break 2 form 2 products for 1 yarpecules.
# Reactive atoms defined as: []
#    + Enumerated 3 products
#    + Applying Lewis score cutoff of 0.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 3 products after filtering

# %% [markdown]
# In sequential enumeration, the same b2f2 exploration of the same molecule results in 33 potential products!!
#
# Most of these are "unreasonable", so when we apply our filters, we extract the same products found (more efficiently) by concerted enumeration.

# %%
haa_seq_b2f2 = enumerate_products(haa, n_break=2, n_form=2, mode='sequential', verbose=True)
haa_seq_b2f2 = filter_enum_products(haa_seq_b2f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False, verbose=True)
for _ in haa_seq_b2f2:
    _.draw_bmats(show_inline=True)
# Out:
#   * Product enumeration with break 2, form 2 will be performed in sequential mode.
#    WARNING: Sequential mode is expensive and may cause memory blow-up issues!
#    + Breaking 2 bonds formed 6 intermediates
#    + Forming 2 bonds formed 33 potential products
#    + Returning total 39 potential products
#    + Applying Lewis score cutoff of 0.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 3 products after filtering

# %% [markdown]
# Why even bother with sequential enumeration then?
# - It gives us more flexibility to discover certain chemistries than concerted enumeration
# - For instance, it's the only option we have for generating radicals from closed-shell species.
#
# Here is a break-2, form-1 enumeration, which will leave unpaired electrons in the final product.
# - NOTE: We must change the default Lewis score cutoff, as unpaired electrons almost always result in a score > 0.0

# %%
haa_seq_b2f1 = enumerate_products(haa, n_break=2, n_form=1, mode='sequential', verbose=True)
haa_seq_b2f1 = filter_enum_products(haa_seq_b2f1, l_cutoff=5.0, fc_cutoff=2.0, ring_filter=False, verbose=True)
for _ in haa_seq_b2f1:
    _.draw_bmats(show_inline=True)
# Out:
#   * Product enumeration with break 2, form 1 will be performed in sequential mode.
#    WARNING: Sequential mode is expensive and may cause memory blow-up issues!
#    + Breaking 2 bonds formed 6 intermediates
#    + Forming 1 bonds formed 16 potential products
#    + Returning total 22 potential products
#    + Applying Lewis score cutoff of 5.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 5 products after filtering

# %% [markdown]
# Concerted enumeration is not able to form radical species

# %%
haa_conc_b2f1 = enumerate_products(haa, n_break=2, n_form=1, mode='concerted', verbose=True)
haa_conc_b2f1 = filter_enum_products(haa_conc_b2f1, l_cutoff=5.0, fc_cutoff=2.0, ring_filter=False, verbose=True)
for _ in haa_conc_b2f1:
    _.draw_bmats(show_inline=True)
# Out:
#   * Product enumeration with break 2, form 1 will be performed in concerted mode.
# Enumerating break 2 form 2 products for 1 yarpecules.
# Reactive atoms defined as: []
#    + Enumerated 3 products
#    + Applying Lewis score cutoff of 5.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 3 products after filtering

# %% [markdown]
# ### How many bonds to break?
#
# Most closed-shell organic chemistry can be explored using a series of concerted break-2, form-2 (b2f2) enumeration rounds.
#
# For some cases, such as the famous Diels-Alder reaction, a concerted break-3, form-3 (b3f3) reaction is the preferred mechanism.

# %%
dar = yp.yarpecule('C=CC=C.C=C')
dar.draw_bmats(show_inline=True)

# %%
dap = yp.yarpecule('C1C=CCCC1')
dap.draw_bmats(show_inline=True)

# %%
dar_conc_b2f2 = enumerate_products(dar, n_break=2, n_form=2, mode='concerted', verbose=True)
dar_conc_b2f2 = filter_enum_products(dar_conc_b2f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False, verbose=True)

dar_conc_b2f2_set = set()
for _ in dar_conc_b2f2:
    dar_conc_b2f2_set.add(_.hash)

print(f"DA product present? {dap.hash in dar_conc_b2f2_set}")
# Out:
#   * Product enumeration with break 2, form 2 will be performed in concerted mode.
# Enumerating break 2 form 2 products for 1 yarpecules.
# Reactive atoms defined as: []
#    + Enumerated 17 products
#    + Applying Lewis score cutoff of 0.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 16 products after filtering
# DA product present? False

# %%
dar_conc_b3f3 = enumerate_products(dar, n_break=3, n_form=3, mode='concerted', verbose=True)
dar_conc_b3f3 = filter_enum_products(dar_conc_b3f3, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False, verbose=True)

dar_conc_b3f3_set = set()
for _ in dar_conc_b3f3:
    dar_conc_b3f3_set.add(_.hash)

print(f"DA product present? {dap.hash in dar_conc_b3f3_set}")
# Out:
#   * Product enumeration with break 3, form 3 will be performed in concerted mode.
# Enumerating break 3 form 3 products for 1 yarpecules.
# Reactive atoms defined as: []
#    + Enumerated 48 products
#    + Applying Lewis score cutoff of 0.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 46 products after filtering
# DA product present? True

# %% [markdown]
# As you can see, b3f3 is much more expensive than b2f2.
#
# However, if you need to do b3f3, you can have confidence that you will discover all of the "lower order" b2f2 products in addition to b3f3!

# %%
overlap = dar_conc_b2f2_set & dar_conc_b3f3_set

print(f"b3f3 found {len(overlap)} out of {len(dar_conc_b2f2_set)} b2f2 products!")
# Out:
# b3f3 found 16 out of 16 b2f2 products!

# %% [markdown]
# Fun fact: With how sequential enumeration defines bonds, the Diels-Alder reaction is a break-0, form-2 reaction!
#
# I couldn't get it to work with actually specifying break-0 (add that to the unit testing to-do list), but a break-1, form-2 returns the desired product

# %%
dar_seq_b1f2 = enumerate_products(dar, n_break=1, n_form=2, mode='sequential', verbose=True)
dar_seq_b1f2 = filter_enum_products(dar_seq_b1f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False)

dar_seq_b1f2_set = set()
for _ in dar_seq_b1f2:
    dar_seq_b1f2_set.add(_.hash)

print(f"DA product present? {dap.hash in dar_seq_b1f2_set}")
# Out:
#   * Product enumeration with break 1, form 2 will be performed in sequential mode.
#    WARNING: Sequential mode is expensive and may cause memory blow-up issues!
#    + Breaking 1 bonds formed 4 intermediates
#    + Forming 2 bonds formed 229 potential products
#    + Returning total 233 potential products
# DA product present? True

# %% [markdown]
# ### Enumerating from resonance structures

# %% [markdown]
# The presence of resonance structures **AND** lone pair valence electrons results in a dramatic cost explosion for sequential enumeration!

# %%
benz_smi = "c1ccccc1"
benz_mol = yp.yarpecule(benz_smi)
benz_mol.draw_bmats(show_inline=True)

# %%
benz_seq_b2f2 = enumerate_products(benz_mol, n_break=2, n_form=2, mode='sequential', verbose=True)
benz_seq_b2f2 = filter_enum_products(benz_seq_b2f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False, verbose=False)
# Out:
#   * Product enumeration with break 2, form 2 will be performed in sequential mode.
#    WARNING: Sequential mode is expensive and may cause memory blow-up issues!
#    + Breaking 2 bonds formed 16 intermediates
#    + Forming 2 bonds formed 722 potential products
#    + Returning total 738 potential products

# %%
nbenz_smi = "n1ccccc1"
nbenz_mol = yp.yarpecule(nbenz_smi)
nbenz_mol.draw_bmats(show_inline=True)

# %%
nbenz_seq_b2f2 = enumerate_products(nbenz_mol, n_break=2, n_form=2, mode='sequential', verbose=True)
nbenz_seq_b2f2 = filter_enum_products(nbenz_seq_b2f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False, verbose=True)
# Out:
#   * Product enumeration with break 2, form 2 will be performed in sequential mode.
#    WARNING: Sequential mode is expensive and may cause memory blow-up issues!
#    + Breaking 2 bonds formed 38 intermediates
#    + Forming 2 bonds formed 3812 potential products
#    + Returning total 3850 potential products
#    + Applying Lewis score cutoff of 0.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 626 products after filtering

# %% [markdown]
# Bimolecular enumeration adds an additional cost!

# %%
snar_r = yp.yarpecule('c1ccccc1Cl.O')
snar_r.draw_bmats(show_inline=True)

# %%
snar_p = yp.yarpecule('c1ccccc1O.Cl')
snar_p.draw_bmats(show_inline=True)

# %% [markdown]
# This is pretty much why we have re-implemented concerted enumeration in YARP-again.... it's SO much faster!

# %%
snar_conc_b2f2 = enumerate_products(snar_r, n_break=2, n_form=2, mode='concerted', verbose=True)
snar_conc_b2f2 = filter_enum_products(snar_conc_b2f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False, verbose=True)

snar_conc_b2f2_set = set()
for _ in snar_conc_b2f2:
    snar_conc_b2f2_set.add(_.hash)

print(f"Product found? {snar_p.hash in snar_conc_b2f2_set}")
# Out:
#   * Product enumeration with break 2, form 2 will be performed in concerted mode.
# Enumerating break 2 form 2 products for 1 yarpecules.
# Reactive atoms defined as: []
#    + Enumerated 33 products
#    + Applying Lewis score cutoff of 0.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 31 products after filtering
# Product found? True

# %% [markdown]
# I ran out of patience here, feel free to wait for 1-2 hours for this to finish on your own time!

# %%
snar_seq_b2f2 = enumerate_products(snar_r, n_break=2, n_form=2, mode='sequential', verbose=True)
snar_seq_b2f2 = filter_enum_products(snar_seq_b2f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False, verbose=True)

snar_seq_b2f2_set = set()
for _ in snar_seq_b2f2:
    snar_seq_b2f2_set.add(_.hash)

print(f"Product found? {snar_p.hash in snar_seq_b2f2_set}")
# Out:
#   * Product enumeration with break 2, form 2 will be performed in sequential mode.
#    WARNING: Sequential mode is expensive and may cause memory blow-up issues!
#    + Breaking 2 bonds formed 61 intermediates
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 snar_seq_b2f2 = enumerate_products(snar_r, n_break=2, n_form=2, mode='sequential')
#       2 snar_seq_b2f2 = filter_enum_products(snar_seq_b2f2, l_cutoff=0.0, fc_cutoff=2.0, ring_filter=False)
#       4 snar_seq_b2f2_set = set()
#
# File ~/dev/yarp-again/yarp/reaction/enum.py:67, in enumerate_products(r_yp, n_break, n_form, react, mode)
#      63     print(f"   + Breaking {n_break} bonds formed "
#      64           f"{len(break_mol)} intermediates")
#      66     # Form bonds
# ---> 67     products = form_n_bonds(break_mol, n=n_form, react=react, hashes={r_yp.hash})
#      68     print(f"   + Forming {n_form} bonds formed "
#      69           f"{len(products)} potential products")
#      71 elif mode == "concerted":
#
# File ~/dev/yarp-again/yarp/reaction/enum.py:235, in form_n_bonds(yarpecules, n, react, hashes, inter, intra, def_only, hash_filter)
#     233 while nf<n:
#     234     for y in new:
# --> 235         newest = list(form_bonds(y,hashes=hashes, def_only=def_only))
#     236         hashes.update([ _.hash for _ in newest ])
#     237         new += newest
#
# File ~/dev/yarp-again/yarp/reaction/enum.py:165, in form_bonds(yarpecules, react, hashes, inter, intra, def_only, hash_filter)
#     163 adj_mat[acceptor,donor] = 1
#     164 bonds.update([(donor,acceptor),(acceptor,donor)])
# --> 165 product = yarpecule((adj_mat,y.geo,y.elements,y.q),canon=False)
#     166 if product.hash not in hashes:
#     167     yield product
#
# File ~/dev/yarp-again/yarp/yarpecule/yarpecule.py:103, in yarpecule.__init__(self, mol, mode, canon)
#     100 self._bond_order_dict = None
#     101 self._yarpecule_hash = None
# --> 103 self._gen_lewis_struct()
#     105 # These attributes should be set once enumeration is complete
#     106 # Too many errors/warnings show up in RDkit/Open Babel
#     107 self._canon_smi = None
#
# File ~/dev/yarp-again/yarp/yarpecule/yarpecule.py:318, in yarpecule._gen_lewis_struct(self)
#     308 def _gen_lewis_struct(self):
#     309     """
#     310     Compute Lewis structure(s) for the yarpecule.
#     311     Also update the yarpecule hash while we're at it?
#    (...)    315     self.lewis_struct
#     316     """
# --> 318     self._lewis_struct = lewis_struct(
#     319         self._adj_mat, self._elements, self._q)
#     321     self._bond_order_dict = return_bo_dict(self)
#     323     self._yarpecule_hash = yarpecule_hash(self)
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/lewis_structure.py:90, in lewis_struct.__init__(self, adj_mat, elements, q)
#      87 self._bond_mats = None
#      88 self._scores = None
# ---> 90 self._gen_bond_el_mat(adj_mat, elements, q)
#      92 self._e_acceptors = None
#      93 self._e_donors = None
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/lewis_structure.py:267, in lewis_struct._gen_bond_el_mat(self, adj_mat, elements, q, mats_max, mats_thresh, w_def, w_exp, w_formal, w_aro, w_rad, local_opt)
#     265         bond_mats += [bond_mat]
#     266         hashes.add(bmat_hash(bond_mat))
# --> 267         bond_mats, scores, _, _, _ = gen_all_lstructs(obj_fun, bond_mats, scores, hashes,
#     268                                                       elements, reactive, self._rings, ring_atoms, bridgeheads,
#     269                                                       seps=np.zeros(
#     270                                                           [len(elements), len(elements)]),
#     271                                                       min_score=scores[0], ind=len(bond_mats)-1, N_score=1000,
#     272                                                       N_max=10000, min_win=100.0, min_opt=True)
#     274 # Update objective function to include (anti)aromaticity considerations and update scores of the current bmats
#     275 def obj_fun(x): return bmat_score(x, elements, self._rings, cat_en=en, an_en=en,
#     276                                   rad_env=np.zeros(len(elements)), e_def=e_def,
#     277                                   e_exp=e_exp, w_def=w_def, w_exp=w_exp, w_formal=w_formal,
#     278                                   w_aro=w_aro, w_rad=w_rad, factor=factor, verbose=False)
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/support_dump.py:323, in gen_all_lstructs(obj_fun, bond_mats, scores, hashes, elements, reactive, rings, ring_atoms, bridgeheads, seps, min_score, ind, counter, N_score, N_max, min_opt, min_win)
#     320             hashes.add(b_hash)
#     322             # Recursively call this function with the updated bond_mat resulting from this iteration's move.
# --> 323             bond_mats, scores, hashes, min_score, counter = gen_all_lstructs(obj_fun, bond_mats, scores, hashes, elements,
#     324                                                                              reactive, rings, ring_atoms, bridgeheads, seps, min_score,
#     325                                                                              ind=len(bond_mats)-1, counter=counter, N_score=N_score,
#     326                                                                              N_max=N_max, min_opt=min_opt, min_win=min_win)
#     328 else:
#     329     # min_win option allows the search to follow structures that increase the score up to min_win above the score of the best structure
#     330     if min_win:
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/support_dump.py:323, in gen_all_lstructs(obj_fun, bond_mats, scores, hashes, elements, reactive, rings, ring_atoms, bridgeheads, seps, min_score, ind, counter, N_score, N_max, min_opt, min_win)
#     320             hashes.add(b_hash)
#     322             # Recursively call this function with the updated bond_mat resulting from this iteration's move.
# --> 323             bond_mats, scores, hashes, min_score, counter = gen_all_lstructs(obj_fun, bond_mats, scores, hashes, elements,
#     324                                                                              reactive, rings, ring_atoms, bridgeheads, seps, min_score,
#     325                                                                              ind=len(bond_mats)-1, counter=counter, N_score=N_score,
#     326                                                                              N_max=N_max, min_opt=min_opt, min_win=min_win)
#     328 else:
#     329     # min_win option allows the search to follow structures that increase the score up to min_win above the score of the best structure
#     330     if min_win:
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/support_dump.py:323, in gen_all_lstructs(obj_fun, bond_mats, scores, hashes, elements, reactive, rings, ring_atoms, bridgeheads, seps, min_score, ind, counter, N_score, N_max, min_opt, min_win)
#     320             hashes.add(b_hash)
#     322             # Recursively call this function with the updated bond_mat resulting from this iteration's move.
# --> 323             bond_mats, scores, hashes, min_score, counter = gen_all_lstructs(obj_fun, bond_mats, scores, hashes, elements,
#     324                                                                              reactive, rings, ring_atoms, bridgeheads, seps, min_score,
#     325                                                                              ind=len(bond_mats)-1, counter=counter, N_score=N_score,
#     326                                                                              N_max=N_max, min_opt=min_opt, min_win=min_win)
#     328 else:
#     329     # min_win option allows the search to follow structures that increase the score up to min_win above the score of the best structure
#     330     if min_win:
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/support_dump.py:298, in gen_all_lstructs(obj_fun, bond_mats, scores, hashes, elements, reactive, rings, ring_atoms, bridgeheads, seps, min_score, ind, counter, N_score, N_max, min_opt, min_win)
#     295     tmp[k[1], k[2]] += k[0]
#     297 # calc objective function and hash value
# --> 298 score = obj_fun(tmp)
#     299 b_hash = bmat_hash(tmp)
#     301 # Check if a new best Lewis structure has been found, if so, then reset counter and record new best score
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/lewis_structure.py:250, in lewis_struct._gen_bond_el_mat.<locals>.obj_fun(x)
# --> 250 def obj_fun(x): return bmat_score(x, elements, self._rings, cat_en=en, an_en=en,
#     251                                   rad_env=np.zeros(len(elements)), e_def=e_def,
#     252                                   e_exp=e_exp, w_def=w_def, w_exp=w_exp, w_formal=w_formal,
#     253                                   # aro term is turned off initially since it traps greedy optimization
#     254                                   w_aro=0, w_rad=w_rad, factor=factor, verbose=False)
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/be_mat.py:113, in bmat_score(bond_mat, elements, rings, cat_en, an_en, rad_env, e_def, e_exp, w_def, w_exp, w_formal, w_aro, w_rad, factor, verbose)
#     109     print("radicals: {}".format(
#     110         w_rad*sum([rad_env[_]*(bond_mat[_, _] % 2) for _ in range(len(bond_mat))])))
#     112 # objective function (lower is better): sum ( electron_deficiency * electronegativity_of_atom ) + sum ( expanded_octets ) + sum ( formal charge * electronegativity_of_atom ) + sum ( aromaticity of rings ) + factor
# --> 113 return w_def*sum([_*en[count] for count, _ in enumerate(return_def(bond_mat, elements, e_def))]) + \
#     114     w_exp*sum(return_expanded(bond_mat, elements, e_exp)) + \
#     115     w_formal*sum([_ * en[count]*np.exp(0.05*(_-1)) for count, _ in enumerate(return_formals(bond_mat, elements))]) + \
#     116     w_aro*sum([is_aromatic(bond_mat, _)/len(_) for _ in rings]) + \
#     117     w_rad*sum([rad_env[_]*(bond_mat[_, _] % 2)
#     118               for _ in range(len(bond_mat))]) + factor
#
# File ~/dev/yarp-again/yarp/yarpecule/lewis/be_mat.py:113, in <listcomp>(.0)
#     109     print("radicals: {}".format(
#     110         w_rad*sum([rad_env[_]*(bond_mat[_, _] % 2) for _ in range(len(bond_mat))])))
#     112 # objective function (lower is better): sum ( electron_deficiency * electronegativity_of_atom ) + sum ( expanded_octets ) + sum ( formal charge * electronegativity_of_atom ) + sum ( aromaticity of rings ) + factor
# --> 113 return w_def*sum([_*en[count] for count, _ in enumerate(return_def(bond_mat, elements, e_def))]) + \
#     114     w_exp*sum(return_expanded(bond_mat, elements, e_exp)) + \
#     115     w_formal*sum([_ * en[count]*np.exp(0.05*(_-1)) for count, _ in enumerate(return_formals(bond_mat, elements))]) + \
#     116     w_aro*sum([is_aromatic(bond_mat, _)/len(_) for _ in rings]) + \
#     117     w_rad*sum([rad_env[_]*(bond_mat[_, _] % 2)
#     118               for _ in range(len(bond_mat))]) + factor
#
# KeyboardInterrupt:

# %% [markdown]
# ## Section B: Reaction Object Class
#
# Ok, so you have your enumerated products, but now what do you do with them?
#
# YARP-again stores pairs of reactant-product yarpecules inside of reaction class objects! Let's look at the structure of a reaction class.

# %%
from yarp.reaction.reaction import reaction

# %% [markdown]
# The reaction class is initialized with several placeholders for downstream applications (i.e. reaction characterization)

# %%
# Minimal functionality example from yarp/reactions/generate_reaction.py --> generate_rxns()

reactant = yp.yarpecule('CC=O')
products = enumerate_products(reactant, n_break=2, n_form=2, verbose=True)
products = filter_enum_products(products, verbose=True)

output = dict()
for i, prod in enumerate(products):
    # Do a quick optimization to make product geometries reflect new bonding (needs debugging!)
    # prod = quick_geom_opt(prod, inp.quick_opt_lot)

    # Generate a reaction object from reactant/product pairs
    rxn = reaction(reactant, prod)

    # Add reaction to dictionary paired with its ID
    output[rxn.hash] = rxn

print(f"We now have {len(output)} reactions!")
# Out:
#   * Product enumeration with break 2, form 2 will be performed in concerted mode.
# Enumerating break 2 form 2 products for 1 yarpecules.
# Reactive atoms defined as: []
#    + Enumerated 3 products
#    + Applying Lewis score cutoff of 0.0
#    + Applying formal charge cutoff of 2.0
#    + Returning 3 products after filtering
# We now have 3 reactions!

# %% [markdown]
# The reactant and product yarpecules now live in `state` objects, which store some helpful additional information

# %%
for rxn in output.values():
    print(rxn.id)
    print(f" - Product state: {rxn.product.canon_smi}")
    for mol in rxn.product.species:
        print(f"  + Species: {mol.canon_smi}")
# Out:
# IKHGUXGNUITLKF_to_IMROMDMJAWUWLK
#  - Product state: C=CO
#   + Species: C=CO
# IKHGUXGNUITLKF_to_IAYPIBMASNFSPL
#  - Product state: C1CO1
#   + Species: C1CO1
# IKHGUXGNUITLKF_to_CCGKOQOJPYTBIH-UFHFLCQGNIYNRP
#  - Product state: C=C=O.[H][H]
#   + Species: C=C=O
#   + Species: [H][H]
