# %% [markdown]
# >Playground for developing the tests associated with Brett's Lewis structure test case dump.
#
# Will primarily be used for testing the find_lewis function on all the xyz files under "../test/molecules/fls"

# %%
import pprint
import yarp as yp
ROOT = "../test/molecules/find_lewis_inputs/"
FILE = "tropone.xyz"

# %% [markdown]
# ***Non exhaustive list of all the outputs of "find_lewis" that can be considered for testing:***
#
# bond_mats:
# elements,
# rings,
# cat_en,
# an_en,
# rad_env,
# e_def,
# e_exp,
# w_def,
# w_exp,
# w_formal,
# w_aro,
# w_rad,
# factor,
# is_aromatic,
#
# Lewis Structure:
# rings,
# scores,
# e_acceptors,
# e_donors,
# formal_charge,
# atom_neighbors,
# bo_dict,

# %%
#Load in 1-methyl-3-buteneium as a yarpecule and draw its bond matrix
y_i = yp.yarpecule(ROOT + FILE)

y_i.draw_bmats(show_inline=True)

# %% [markdown]
# Print all the internal attributes of the yarpecule

# %%
#print(f"File Name: {FILE}")
#print(f"Elements: {y_i.elements}")
#print(f"Formal Charge: {y_i.fc}")
#print(f"Scores: {y_i.bond_mat_scores}")
#print(f"Rings:\n{y_i.rings}")
#print(f"E_Accepters: {y_i.n_e_accept}")
#print(f"E_Donors: {y_i.n_e_donate}")
#print(f"atom_neighbors: {y_i.atom_neighbors}")
#print(f"Adj Mat:\n{y_i.adj_mat}")
#print(f"Bond Mat:\n{y_i.bond_mats}")
#print(f"Charge: {y_i.q}")

# %%
print("Yarpecule Charge:", y_i.q)
# Out:
# Yarpecule Charge: 0

# %%
print("Elements with Indexes:")
for idx, elem in enumerate(y_i.elements):
    print(f"yarpecule.elements[{idx}] = {elem}")
# Out:
# Elements with Indexes:
# yarpecule.elements[0] = c
# yarpecule.elements[1] = c
# yarpecule.elements[2] = c
# yarpecule.elements[3] = c
# yarpecule.elements[4] = c
# yarpecule.elements[5] = c
# yarpecule.elements[6] = c
# yarpecule.elements[7] = o
# yarpecule.elements[8] = h
# yarpecule.elements[9] = h
# yarpecule.elements[10] = h
# yarpecule.elements[11] = h
# yarpecule.elements[12] = h
# yarpecule.elements[13] = h

# %%
print("Formal Charges with Indexes:")
for idx, fc in enumerate(y_i.fc):
    print(f"yarpecule.fc[{idx}] = {fc}")
# Out:
# Formal Charges with Indexes:
# yarpecule.fc[0] = 0.0
# yarpecule.fc[1] = 0.0
# yarpecule.fc[2] = 0.0
# yarpecule.fc[3] = 0.0
# yarpecule.fc[4] = 0.0
# yarpecule.fc[5] = 0.0
# yarpecule.fc[6] = 0.0
# yarpecule.fc[7] = 0.0
# yarpecule.fc[8] = 0.0
# yarpecule.fc[9] = 0.0
# yarpecule.fc[10] = 0.0
# yarpecule.fc[11] = 0.0
# yarpecule.fc[12] = 0.0
# yarpecule.fc[13] = 0.0

# %%
print("Bond Matrices Scores with Indexes:")
for idx, score in enumerate(y_i.bond_mat_scores):
    print(f"yarpecule.bond_mat_scores[{idx}] = {score}")
# Out:
# Bond Matrices Scores with Indexes:
# yarpecule.bond_mat_scores[0] = 0.0

# %%
print("Rings with Indexes:")
for idx, ring in enumerate(y_i.rings):
    print(f"yarpecule.rings[{idx}] = {ring}")
# Out:
# Rings with Indexes:
# yarpecule.rings[0] = [0, np.int64(1), np.int64(4), np.int64(6), np.int64(5), np.int64(3), np.int64(2)]

# %%
print("E Acceptors with Indexes:")
for idx, e_acceptor in enumerate(y_i.n_e_accept):
    print(f"yarpecule.n_e_accept[{idx}] = {e_acceptor}")
# Out:
# E Acceptors with Indexes:
# yarpecule.n_e_accept[0] = 2.0
# yarpecule.n_e_accept[1] = 2.0
# yarpecule.n_e_accept[2] = 2.0
# yarpecule.n_e_accept[3] = 2.0
# yarpecule.n_e_accept[4] = 2.0
# yarpecule.n_e_accept[5] = 2.0
# yarpecule.n_e_accept[6] = 2.0
# yarpecule.n_e_accept[7] = 2.0
# yarpecule.n_e_accept[8] = 0.0
# yarpecule.n_e_accept[9] = 0.0
# yarpecule.n_e_accept[10] = 0.0
# yarpecule.n_e_accept[11] = 0.0
# yarpecule.n_e_accept[12] = 0.0
# yarpecule.n_e_accept[13] = 0.0

# %%
print("E Donors with Indexes:")
for idx, e_donor in enumerate(y_i.n_e_donate):
    print(f"yarpecule.n_e_donate[{idx}] = {e_donor}")
# Out:
# E Donors with Indexes:
# yarpecule.n_e_donate[0] = 2.0
# yarpecule.n_e_donate[1] = 2.0
# yarpecule.n_e_donate[2] = 2.0
# yarpecule.n_e_donate[3] = 2.0
# yarpecule.n_e_donate[4] = 2.0
# yarpecule.n_e_donate[5] = 2.0
# yarpecule.n_e_donate[6] = 2.0
# yarpecule.n_e_donate[7] = 6.0
# yarpecule.n_e_donate[8] = 0.0
# yarpecule.n_e_donate[9] = 0.0
# yarpecule.n_e_donate[10] = 0.0
# yarpecule.n_e_donate[11] = 0.0
# yarpecule.n_e_donate[12] = 0.0
# yarpecule.n_e_donate[13] = 0.0

# %%
print("Atom Neighbors with Indexes:")
for idx, neighbors in enumerate(y_i.atom_neighbors):
    print(f"yarpecule.atom_neighbors[{idx}] = {neighbors}")
# Out:
# Atom Neighbors with Indexes:
# yarpecule.atom_neighbors[0] = {0, 1, 2, 7}
# yarpecule.atom_neighbors[1] = {0, 1, 4, 8}
# yarpecule.atom_neighbors[2] = {0, 9, 2, 3}
# yarpecule.atom_neighbors[3] = {11, 2, 3, 5}
# yarpecule.atom_neighbors[4] = {1, 10, 4, 6}
# yarpecule.atom_neighbors[5] = {3, 12, 5, 6}
# yarpecule.atom_neighbors[6] = {13, 4, 5, 6}
# yarpecule.atom_neighbors[7] = {0, 7}
# yarpecule.atom_neighbors[8] = {8, 1}
# yarpecule.atom_neighbors[9] = {9, 2}
# yarpecule.atom_neighbors[10] = {10, 4}
# yarpecule.atom_neighbors[11] = {3, 11}
# yarpecule.atom_neighbors[12] = {12, 5}
# yarpecule.atom_neighbors[13] = {13, 6}

# %%
print("Bond Matrix Elements with Indexes:")
for bmat_idx, bond_mat in enumerate(y_i.bond_mats):
    print(f"yarpecule.bond_mats[{bmat_idx}]")
    for row_idx, row in enumerate(bond_mat):
        print(f"    yarpecule.bond_mats[{bmat_idx}][{row_idx}]")
        for column_idx, column in enumerate(row):
            print(f"        yarpecule.bond_mats[{bmat_idx}][{row_idx}][{column_idx}] = {column}")
# Out:
# Bond Matrix Elements with Indexes:
# yarpecule.bond_mats[0]
#     yarpecule.bond_mats[0][0]
#         yarpecule.bond_mats[0][0][0] = 0.0
#         yarpecule.bond_mats[0][0][1] = 1.0
#         yarpecule.bond_mats[0][0][2] = 1.0
#         yarpecule.bond_mats[0][0][3] = 0.0
#         yarpecule.bond_mats[0][0][4] = 0.0
#         yarpecule.bond_mats[0][0][5] = 0.0
#         yarpecule.bond_mats[0][0][6] = 0.0
#         yarpecule.bond_mats[0][0][7] = 2.0
#         yarpecule.bond_mats[0][0][8] = 0.0
#         yarpecule.bond_mats[0][0][9] = 0.0
#         yarpecule.bond_mats[0][0][10] = 0.0
#         yarpecule.bond_mats[0][0][11] = 0.0
#         yarpecule.bond_mats[0][0][12] = 0.0
#         yarpecule.bond_mats[0][0][13] = 0.0
#     yarpecule.bond_mats[0][1]
#         yarpecule.bond_mats[0][1][0] = 1.0
#         yarpecule.bond_mats[0][1][1] = 0.0
#         yarpecule.bond_mats[0][1][2] = 0.0
#         yarpecule.bond_mats[0][1][3] = 0.0
#         yarpecule.bond_mats[0][1][4] = 2.0
#         yarpecule.bond_mats[0][1][5] = 0.0
#         yarpecule.bond_mats[0][1][6] = 0.0
#         yarpecule.bond_mats[0][1][7] = 0.0
#         yarpecule.bond_mats[0][1][8] = 1.0
#         yarpecule.bond_mats[0][1][9] = 0.0
#         yarpecule.bond_mats[0][1][10] = 0.0
#         yarpecule.bond_mats[0][1][11] = 0.0
#         yarpecule.bond_mats[0][1][12] = 0.0
#         yarpecule.bond_mats[0][1][13] = 0.0
#     yarpecule.bond_mats[0][2]
#         yarpecule.bond_mats[0][2][0] = 1.0
#         yarpecule.bond_mats[0][2][1] = 0.0
#         yarpecule.bond_mats[0][2][2] = 0.0
#         yarpecule.bond_mats[0][2][3] = 2.0
#         yarpecule.bond_mats[0][2][4] = 0.0
#         yarpecule.bond_mats[0][2][5] = 0.0
#         yarpecule.bond_mats[0][2][6] = 0.0
#         yarpecule.bond_mats[0][2][7] = 0.0
#         yarpecule.bond_mats[0][2][8] = 0.0
#         yarpecule.bond_mats[0][2][9] = 1.0
#         yarpecule.bond_mats[0][2][10] = 0.0
#         yarpecule.bond_mats[0][2][11] = 0.0
#         yarpecule.bond_mats[0][2][12] = 0.0
#         yarpecule.bond_mats[0][2][13] = 0.0
#     yarpecule.bond_mats[0][3]
#         yarpecule.bond_mats[0][3][0] = 0.0
#         yarpecule.bond_mats[0][3][1] = 0.0
#         yarpecule.bond_mats[0][3][2] = 2.0
#         yarpecule.bond_mats[0][3][3] = 0.0
#         yarpecule.bond_mats[0][3][4] = 0.0
#         yarpecule.bond_mats[0][3][5] = 1.0
#         yarpecule.bond_mats[0][3][6] = 0.0
#         yarpecule.bond_mats[0][3][7] = 0.0
#         yarpecule.bond_mats[0][3][8] = 0.0
#         yarpecule.bond_mats[0][3][9] = 0.0
#         yarpecule.bond_mats[0][3][10] = 0.0
#         yarpecule.bond_mats[0][3][11] = 1.0
#         yarpecule.bond_mats[0][3][12] = 0.0
#         yarpecule.bond_mats[0][3][13] = 0.0
#     yarpecule.bond_mats[0][4]
#         yarpecule.bond_mats[0][4][0] = 0.0
#         yarpecule.bond_mats[0][4][1] = 2.0
#         yarpecule.bond_mats[0][4][2] = 0.0
#         yarpecule.bond_mats[0][4][3] = 0.0
#         yarpecule.bond_mats[0][4][4] = 0.0
#         yarpecule.bond_mats[0][4][5] = 0.0
#         yarpecule.bond_mats[0][4][6] = 1.0
#         yarpecule.bond_mats[0][4][7] = 0.0
#         yarpecule.bond_mats[0][4][8] = 0.0
#         yarpecule.bond_mats[0][4][9] = 0.0
#         yarpecule.bond_mats[0][4][10] = 1.0
#         yarpecule.bond_mats[0][4][11] = 0.0
#         yarpecule.bond_mats[0][4][12] = 0.0
#         yarpecule.bond_mats[0][4][13] = 0.0
#     yarpecule.bond_mats[0][5]
#         yarpecule.bond_mats[0][5][0] = 0.0
#         yarpecule.bond_mats[0][5][1] = 0.0
#         yarpecule.bond_mats[0][5][2] = 0.0
#         yarpecule.bond_mats[0][5][3] = 1.0
#         yarpecule.bond_mats[0][5][4] = 0.0
#         yarpecule.bond_mats[0][5][5] = 0.0
#         yarpecule.bond_mats[0][5][6] = 2.0
#         yarpecule.bond_mats[0][5][7] = 0.0
#         yarpecule.bond_mats[0][5][8] = 0.0
#         yarpecule.bond_mats[0][5][9] = 0.0
#         yarpecule.bond_mats[0][5][10] = 0.0
#         yarpecule.bond_mats[0][5][11] = 0.0
#         yarpecule.bond_mats[0][5][12] = 1.0
#         yarpecule.bond_mats[0][5][13] = 0.0
#     yarpecule.bond_mats[0][6]
#         yarpecule.bond_mats[0][6][0] = 0.0
#         yarpecule.bond_mats[0][6][1] = 0.0
#         yarpecule.bond_mats[0][6][2] = 0.0
#         yarpecule.bond_mats[0][6][3] = 0.0
#         yarpecule.bond_mats[0][6][4] = 1.0
#         yarpecule.bond_mats[0][6][5] = 2.0
#         yarpecule.bond_mats[0][6][6] = 0.0
#         yarpecule.bond_mats[0][6][7] = 0.0
#         yarpecule.bond_mats[0][6][8] = 0.0
#         yarpecule.bond_mats[0][6][9] = 0.0
#         yarpecule.bond_mats[0][6][10] = 0.0
#         yarpecule.bond_mats[0][6][11] = 0.0
#         yarpecule.bond_mats[0][6][12] = 0.0
#         yarpecule.bond_mats[0][6][13] = 1.0
#     yarpecule.bond_mats[0][7]
#         yarpecule.bond_mats[0][7][0] = 2.0
#         yarpecule.bond_mats[0][7][1] = 0.0
#         yarpecule.bond_mats[0][7][2] = 0.0
#         yarpecule.bond_mats[0][7][3] = 0.0
#         yarpecule.bond_mats[0][7][4] = 0.0
#         yarpecule.bond_mats[0][7][5] = 0.0
#         yarpecule.bond_mats[0][7][6] = 0.0
#         yarpecule.bond_mats[0][7][7] = 4.0
#         yarpecule.bond_mats[0][7][8] = 0.0
#         yarpecule.bond_mats[0][7][9] = 0.0
#         yarpecule.bond_mats[0][7][10] = 0.0
#         yarpecule.bond_mats[0][7][11] = 0.0
#         yarpecule.bond_mats[0][7][12] = 0.0
#         yarpecule.bond_mats[0][7][13] = 0.0
#     yarpecule.bond_mats[0][8]
#         yarpecule.bond_mats[0][8][0] = 0.0
#         yarpecule.bond_mats[0][8][1] = 1.0
#         yarpecule.bond_mats[0][8][2] = 0.0
#         yarpecule.bond_mats[0][8][3] = 0.0
#         yarpecule.bond_mats[0][8][4] = 0.0
#         yarpecule.bond_mats[0][8][5] = 0.0
#         yarpecule.bond_mats[0][8][6] = 0.0
#         yarpecule.bond_mats[0][8][7] = 0.0
#         yarpecule.bond_mats[0][8][8] = 0.0
#         yarpecule.bond_mats[0][8][9] = 0.0
#         yarpecule.bond_mats[0][8][10] = 0.0
#         yarpecule.bond_mats[0][8][11] = 0.0
#         yarpecule.bond_mats[0][8][12] = 0.0
#         yarpecule.bond_mats[0][8][13] = 0.0
#     yarpecule.bond_mats[0][9]
#         yarpecule.bond_mats[0][9][0] = 0.0
#         yarpecule.bond_mats[0][9][1] = 0.0
#         yarpecule.bond_mats[0][9][2] = 1.0
#         yarpecule.bond_mats[0][9][3] = 0.0
#         yarpecule.bond_mats[0][9][4] = 0.0
#         yarpecule.bond_mats[0][9][5] = 0.0
#         yarpecule.bond_mats[0][9][6] = 0.0
#         yarpecule.bond_mats[0][9][7] = 0.0
#         yarpecule.bond_mats[0][9][8] = 0.0
#         yarpecule.bond_mats[0][9][9] = 0.0
#         yarpecule.bond_mats[0][9][10] = 0.0
#         yarpecule.bond_mats[0][9][11] = 0.0
#         yarpecule.bond_mats[0][9][12] = 0.0
#         yarpecule.bond_mats[0][9][13] = 0.0
#     yarpecule.bond_mats[0][10]
#         yarpecule.bond_mats[0][10][0] = 0.0
#         yarpecule.bond_mats[0][10][1] = 0.0
#         yarpecule.bond_mats[0][10][2] = 0.0
#         yarpecule.bond_mats[0][10][3] = 0.0
#         yarpecule.bond_mats[0][10][4] = 1.0
#         yarpecule.bond_mats[0][10][5] = 0.0
#         yarpecule.bond_mats[0][10][6] = 0.0
#         yarpecule.bond_mats[0][10][7] = 0.0
#         yarpecule.bond_mats[0][10][8] = 0.0
#         yarpecule.bond_mats[0][10][9] = 0.0
#         yarpecule.bond_mats[0][10][10] = 0.0
#         yarpecule.bond_mats[0][10][11] = 0.0
#         yarpecule.bond_mats[0][10][12] = 0.0
#         yarpecule.bond_mats[0][10][13] = 0.0
#     yarpecule.bond_mats[0][11]
#         yarpecule.bond_mats[0][11][0] = 0.0
#         yarpecule.bond_mats[0][11][1] = 0.0
#         yarpecule.bond_mats[0][11][2] = 0.0
#         yarpecule.bond_mats[0][11][3] = 1.0
#         yarpecule.bond_mats[0][11][4] = 0.0
#         yarpecule.bond_mats[0][11][5] = 0.0
#         yarpecule.bond_mats[0][11][6] = 0.0
#         yarpecule.bond_mats[0][11][7] = 0.0
#         yarpecule.bond_mats[0][11][8] = 0.0
#         yarpecule.bond_mats[0][11][9] = 0.0
#         yarpecule.bond_mats[0][11][10] = 0.0
#         yarpecule.bond_mats[0][11][11] = 0.0
#         yarpecule.bond_mats[0][11][12] = 0.0
#         yarpecule.bond_mats[0][11][13] = 0.0
#     yarpecule.bond_mats[0][12]
#         yarpecule.bond_mats[0][12][0] = 0.0
#         yarpecule.bond_mats[0][12][1] = 0.0
#         yarpecule.bond_mats[0][12][2] = 0.0
#         yarpecule.bond_mats[0][12][3] = 0.0
#         yarpecule.bond_mats[0][12][4] = 0.0
#         yarpecule.bond_mats[0][12][5] = 1.0
#         yarpecule.bond_mats[0][12][6] = 0.0
#         yarpecule.bond_mats[0][12][7] = 0.0
#         yarpecule.bond_mats[0][12][8] = 0.0
#         yarpecule.bond_mats[0][12][9] = 0.0
#         yarpecule.bond_mats[0][12][10] = 0.0
#         yarpecule.bond_mats[0][12][11] = 0.0
#         yarpecule.bond_mats[0][12][12] = 0.0
#         yarpecule.bond_mats[0][12][13] = 0.0
#     yarpecule.bond_mats[0][13]
#         yarpecule.bond_mats[0][13][0] = 0.0
#         yarpecule.bond_mats[0][13][1] = 0.0
#         yarpecule.bond_mats[0][13][2] = 0.0
#         yarpecule.bond_mats[0][13][3] = 0.0
#         yarpecule.bond_mats[0][13][4] = 0.0
#         yarpecule.bond_mats[0][13][5] = 0.0
#         yarpecule.bond_mats[0][13][6] = 1.0
#         yarpecule.bond_mats[0][13][7] = 0.0
#         yarpecule.bond_mats[0][13][8] = 0.0
#         yarpecule.bond_mats[0][13][9] = 0.0
#         yarpecule.bond_mats[0][13][10] = 0.0
#         yarpecule.bond_mats[0][13][11] = 0.0
#         yarpecule.bond_mats[0][13][12] = 0.0
#         yarpecule.bond_mats[0][13][13] = 0.0

# %%
print("Adjacency Matrix with indexes, and their indexes:")
for row_idx, row in enumerate(y_i.adj_mat):
    print(f"yarpecule.adj_mat[{row_idx}]")
    for column_idx, column in enumerate(row):
        print(f"  yarpecule.adj_mat[{row_idx}][{column_idx}] = {column}")
# Out:
# Adjacency Matrix with indexes, and their indexes:
# yarpecule.adj_mat[0]
#   yarpecule.adj_mat[0][0] = 0.0
#   yarpecule.adj_mat[0][1] = 1.0
#   yarpecule.adj_mat[0][2] = 1.0
#   yarpecule.adj_mat[0][3] = 0.0
#   yarpecule.adj_mat[0][4] = 0.0
#   yarpecule.adj_mat[0][5] = 0.0
#   yarpecule.adj_mat[0][6] = 0.0
#   yarpecule.adj_mat[0][7] = 1.0
#   yarpecule.adj_mat[0][8] = 0.0
#   yarpecule.adj_mat[0][9] = 0.0
#   yarpecule.adj_mat[0][10] = 0.0
#   yarpecule.adj_mat[0][11] = 0.0
#   yarpecule.adj_mat[0][12] = 0.0
#   yarpecule.adj_mat[0][13] = 0.0
# yarpecule.adj_mat[1]
#   yarpecule.adj_mat[1][0] = 1.0
#   yarpecule.adj_mat[1][1] = 0.0
#   yarpecule.adj_mat[1][2] = 0.0
#   yarpecule.adj_mat[1][3] = 0.0
#   yarpecule.adj_mat[1][4] = 1.0
#   yarpecule.adj_mat[1][5] = 0.0
#   yarpecule.adj_mat[1][6] = 0.0
#   yarpecule.adj_mat[1][7] = 0.0
#   yarpecule.adj_mat[1][8] = 1.0
#   yarpecule.adj_mat[1][9] = 0.0
#   yarpecule.adj_mat[1][10] = 0.0
#   yarpecule.adj_mat[1][11] = 0.0
#   yarpecule.adj_mat[1][12] = 0.0
#   yarpecule.adj_mat[1][13] = 0.0
# yarpecule.adj_mat[2]
#   yarpecule.adj_mat[2][0] = 1.0
#   yarpecule.adj_mat[2][1] = 0.0
#   yarpecule.adj_mat[2][2] = 0.0
#   yarpecule.adj_mat[2][3] = 1.0
#   yarpecule.adj_mat[2][4] = 0.0
#   yarpecule.adj_mat[2][5] = 0.0
#   yarpecule.adj_mat[2][6] = 0.0
#   yarpecule.adj_mat[2][7] = 0.0
#   yarpecule.adj_mat[2][8] = 0.0
#   yarpecule.adj_mat[2][9] = 1.0
#   yarpecule.adj_mat[2][10] = 0.0
#   yarpecule.adj_mat[2][11] = 0.0
#   yarpecule.adj_mat[2][12] = 0.0
#   yarpecule.adj_mat[2][13] = 0.0
# yarpecule.adj_mat[3]
#   yarpecule.adj_mat[3][0] = 0.0
#   yarpecule.adj_mat[3][1] = 0.0
#   yarpecule.adj_mat[3][2] = 1.0
#   yarpecule.adj_mat[3][3] = 0.0
#   yarpecule.adj_mat[3][4] = 0.0
#   yarpecule.adj_mat[3][5] = 1.0
#   yarpecule.adj_mat[3][6] = 0.0
#   yarpecule.adj_mat[3][7] = 0.0
#   yarpecule.adj_mat[3][8] = 0.0
#   yarpecule.adj_mat[3][9] = 0.0
#   yarpecule.adj_mat[3][10] = 0.0
#   yarpecule.adj_mat[3][11] = 1.0
#   yarpecule.adj_mat[3][12] = 0.0
#   yarpecule.adj_mat[3][13] = 0.0
# yarpecule.adj_mat[4]
#   yarpecule.adj_mat[4][0] = 0.0
#   yarpecule.adj_mat[4][1] = 1.0
#   yarpecule.adj_mat[4][2] = 0.0
#   yarpecule.adj_mat[4][3] = 0.0
#   yarpecule.adj_mat[4][4] = 0.0
#   yarpecule.adj_mat[4][5] = 0.0
#   yarpecule.adj_mat[4][6] = 1.0
#   yarpecule.adj_mat[4][7] = 0.0
#   yarpecule.adj_mat[4][8] = 0.0
#   yarpecule.adj_mat[4][9] = 0.0
#   yarpecule.adj_mat[4][10] = 1.0
#   yarpecule.adj_mat[4][11] = 0.0
#   yarpecule.adj_mat[4][12] = 0.0
#   yarpecule.adj_mat[4][13] = 0.0
# yarpecule.adj_mat[5]
#   yarpecule.adj_mat[5][0] = 0.0
#   yarpecule.adj_mat[5][1] = 0.0
#   yarpecule.adj_mat[5][2] = 0.0
#   yarpecule.adj_mat[5][3] = 1.0
#   yarpecule.adj_mat[5][4] = 0.0
#   yarpecule.adj_mat[5][5] = 0.0
#   yarpecule.adj_mat[5][6] = 1.0
#   yarpecule.adj_mat[5][7] = 0.0
#   yarpecule.adj_mat[5][8] = 0.0
#   yarpecule.adj_mat[5][9] = 0.0
#   yarpecule.adj_mat[5][10] = 0.0
#   yarpecule.adj_mat[5][11] = 0.0
#   yarpecule.adj_mat[5][12] = 1.0
#   yarpecule.adj_mat[5][13] = 0.0
# yarpecule.adj_mat[6]
#   yarpecule.adj_mat[6][0] = 0.0
#   yarpecule.adj_mat[6][1] = 0.0
#   yarpecule.adj_mat[6][2] = 0.0
#   yarpecule.adj_mat[6][3] = 0.0
#   yarpecule.adj_mat[6][4] = 1.0
#   yarpecule.adj_mat[6][5] = 1.0
#   yarpecule.adj_mat[6][6] = 0.0
#   yarpecule.adj_mat[6][7] = 0.0
#   yarpecule.adj_mat[6][8] = 0.0
#   yarpecule.adj_mat[6][9] = 0.0
#   yarpecule.adj_mat[6][10] = 0.0
#   yarpecule.adj_mat[6][11] = 0.0
#   yarpecule.adj_mat[6][12] = 0.0
#   yarpecule.adj_mat[6][13] = 1.0
# yarpecule.adj_mat[7]
#   yarpecule.adj_mat[7][0] = 1.0
#   yarpecule.adj_mat[7][1] = 0.0
#   yarpecule.adj_mat[7][2] = 0.0
#   yarpecule.adj_mat[7][3] = 0.0
#   yarpecule.adj_mat[7][4] = 0.0
#   yarpecule.adj_mat[7][5] = 0.0
#   yarpecule.adj_mat[7][6] = 0.0
#   yarpecule.adj_mat[7][7] = 0.0
#   yarpecule.adj_mat[7][8] = 0.0
#   yarpecule.adj_mat[7][9] = 0.0
#   yarpecule.adj_mat[7][10] = 0.0
#   yarpecule.adj_mat[7][11] = 0.0
#   yarpecule.adj_mat[7][12] = 0.0
#   yarpecule.adj_mat[7][13] = 0.0
# yarpecule.adj_mat[8]
#   yarpecule.adj_mat[8][0] = 0.0
#   yarpecule.adj_mat[8][1] = 1.0
#   yarpecule.adj_mat[8][2] = 0.0
#   yarpecule.adj_mat[8][3] = 0.0
#   yarpecule.adj_mat[8][4] = 0.0
#   yarpecule.adj_mat[8][5] = 0.0
#   yarpecule.adj_mat[8][6] = 0.0
#   yarpecule.adj_mat[8][7] = 0.0
#   yarpecule.adj_mat[8][8] = 0.0
#   yarpecule.adj_mat[8][9] = 0.0
#   yarpecule.adj_mat[8][10] = 0.0
#   yarpecule.adj_mat[8][11] = 0.0
#   yarpecule.adj_mat[8][12] = 0.0
#   yarpecule.adj_mat[8][13] = 0.0
# yarpecule.adj_mat[9]
#   yarpecule.adj_mat[9][0] = 0.0
#   yarpecule.adj_mat[9][1] = 0.0
#   yarpecule.adj_mat[9][2] = 1.0
#   yarpecule.adj_mat[9][3] = 0.0
#   yarpecule.adj_mat[9][4] = 0.0
#   yarpecule.adj_mat[9][5] = 0.0
#   yarpecule.adj_mat[9][6] = 0.0
#   yarpecule.adj_mat[9][7] = 0.0
#   yarpecule.adj_mat[9][8] = 0.0
#   yarpecule.adj_mat[9][9] = 0.0
#   yarpecule.adj_mat[9][10] = 0.0
#   yarpecule.adj_mat[9][11] = 0.0
#   yarpecule.adj_mat[9][12] = 0.0
#   yarpecule.adj_mat[9][13] = 0.0
# yarpecule.adj_mat[10]
#   yarpecule.adj_mat[10][0] = 0.0
#   yarpecule.adj_mat[10][1] = 0.0
#   yarpecule.adj_mat[10][2] = 0.0
#   yarpecule.adj_mat[10][3] = 0.0
#   yarpecule.adj_mat[10][4] = 1.0
#   yarpecule.adj_mat[10][5] = 0.0
#   yarpecule.adj_mat[10][6] = 0.0
#   yarpecule.adj_mat[10][7] = 0.0
#   yarpecule.adj_mat[10][8] = 0.0
#   yarpecule.adj_mat[10][9] = 0.0
#   yarpecule.adj_mat[10][10] = 0.0
#   yarpecule.adj_mat[10][11] = 0.0
#   yarpecule.adj_mat[10][12] = 0.0
#   yarpecule.adj_mat[10][13] = 0.0
# yarpecule.adj_mat[11]
#   yarpecule.adj_mat[11][0] = 0.0
#   yarpecule.adj_mat[11][1] = 0.0
#   yarpecule.adj_mat[11][2] = 0.0
#   yarpecule.adj_mat[11][3] = 1.0
#   yarpecule.adj_mat[11][4] = 0.0
#   yarpecule.adj_mat[11][5] = 0.0
#   yarpecule.adj_mat[11][6] = 0.0
#   yarpecule.adj_mat[11][7] = 0.0
#   yarpecule.adj_mat[11][8] = 0.0
#   yarpecule.adj_mat[11][9] = 0.0
#   yarpecule.adj_mat[11][10] = 0.0
#   yarpecule.adj_mat[11][11] = 0.0
#   yarpecule.adj_mat[11][12] = 0.0
#   yarpecule.adj_mat[11][13] = 0.0
# yarpecule.adj_mat[12]
#   yarpecule.adj_mat[12][0] = 0.0
#   yarpecule.adj_mat[12][1] = 0.0
#   yarpecule.adj_mat[12][2] = 0.0
#   yarpecule.adj_mat[12][3] = 0.0
#   yarpecule.adj_mat[12][4] = 0.0
#   yarpecule.adj_mat[12][5] = 1.0
#   yarpecule.adj_mat[12][6] = 0.0
#   yarpecule.adj_mat[12][7] = 0.0
#   yarpecule.adj_mat[12][8] = 0.0
#   yarpecule.adj_mat[12][9] = 0.0
#   yarpecule.adj_mat[12][10] = 0.0
#   yarpecule.adj_mat[12][11] = 0.0
#   yarpecule.adj_mat[12][12] = 0.0
#   yarpecule.adj_mat[12][13] = 0.0
# yarpecule.adj_mat[13]
#   yarpecule.adj_mat[13][0] = 0.0
#   yarpecule.adj_mat[13][1] = 0.0
#   yarpecule.adj_mat[13][2] = 0.0
#   yarpecule.adj_mat[13][3] = 0.0
#   yarpecule.adj_mat[13][4] = 0.0
#   yarpecule.adj_mat[13][5] = 0.0
#   yarpecule.adj_mat[13][6] = 1.0
#   yarpecule.adj_mat[13][7] = 0.0
#   yarpecule.adj_mat[13][8] = 0.0
#   yarpecule.adj_mat[13][9] = 0.0
#   yarpecule.adj_mat[13][10] = 0.0
#   yarpecule.adj_mat[13][11] = 0.0
#   yarpecule.adj_mat[13][12] = 0.0
#   yarpecule.adj_mat[13][13] = 0.0
